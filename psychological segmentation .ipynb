# %%
# loading libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ev_data = pd.read_csv("ev_data.csv")

# %%
ev_data
# Out:
#      age       city            profession marital_stat      education  \
# 0     30  New Delhi  Working Professional       Single  Post Graduate
# 1     27  Ahmedabad                   NaN       Single  Post Graduate
# 2     28       Pune  Working Professional       Single  Post Graduate
# 3     26       Pune              Salaried       Single  Post Graduate
# 4     25       Pune  Working Professional       Single  Post Graduate
# ..   ...        ...                   ...          ...            ...
# 985   32      Delhi              Salaried       Single       Graduate
# 986   30      Pune                    NaN       Single       Graduate
# 987   31       Pune              Salaried       Single       Graduate
# 988   31       Pune                   NaN      Married       Graduate
# 989   27       Pune                   NaN       Single       Graduate
#
#      family_count  annual_income replace_with_ev preferred_ev_type  \
# ...

# %%
ev_data.isnull().sum()
# Out:
# age                          0
# city                         0
# profession                 455
# marital_stat                 0
# education                    0
# family_count                 0
# annual_income                0
# replace_with_ev              0
# preferred_ev_type            0
# think_ev_are_economical      0
# preferred_brand              0
# preferred_price_range        0
# preferred_wheel_count        0
# dtype: int64

# %%
ev_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      990 non-null    int64
#  1   city                     990 non-null    object
#  2   profession               535 non-null    object
#  3   marital_stat             990 non-null    object
#  4   education                990 non-null    object
#  5   family_count             990 non-null    int64
#  6   annual_income            990 non-null    float64
#  7   replace_with_ev          990 non-null    object
#  8   preferred_ev_type        990 non-null    object
#  9   think_ev_are_economical  990 non-null    object
#  10  preferred_brand          990 non-null    object
#  11  preferred_price_range    990 non-null    object
#  12  preferred_wheel_count    990 non-null    int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 100.7+ KB

# %%
ev_data.shape
# Out:
# (990, 13)

# %%
ev_data.describe()
# Out:
#               age  family_count  annual_income  preferred_wheel_count
# count  990.000000    990.000000   9.900000e+02             990.000000
# mean    31.802020      4.116162   2.261180e+06               3.350505
# std     11.279929      1.469488   1.001444e+06               0.886578
# min     15.000000      0.000000  -3.761509e+05               2.000000
# 25%     26.000000      4.000000   1.794900e+06               2.000000
# 50%     29.000000      4.000000   2.329246e+06               4.000000
# 75%     31.000000      5.000000   2.758737e+06               4.000000
# max    118.000000      8.000000   1.282128e+07               4.000000

# %%
df1=ev_data.drop(["profession","education"],axis = 1)

# %%
df1
# Out:
#      age       city marital_stat  family_count  annual_income replace_with_ev  \
# 0     30  New Delhi       Single             4   1.770466e+06             Yes
# 1     27  Ahmedabad       Single             4   7.600731e+05             Yes
# 2     28       Pune       Single             4   2.779701e+06           Maybe
# 3     26       Pune       Single             4   1.473698e+06             Yes
# 4     25       Pune       Single             4   2.430643e+06             Yes
# ..   ...        ...          ...           ...            ...             ...
# 985   32      Delhi       Single             3   2.259379e+06           Maybe
# 986   30      Pune        Single             5   3.353677e+06             Yes
# 987   31       Pune       Single             2   5.689586e+05             Yes
# 988   31       Pune      Married             4   3.162609e+06             Yes
# 989   27       Pune       Single             4   2.042527e+06             Yes
#
# ...

# %%
df1.city.value_counts()
# Out:
# city
# Pune           565
# Mumbai          45
# Pune            37
# Delhi           24
# Nagpur          22
# Satara          21
# New Delhi       19
# Nellore         17
# Banglore        15
# Noida           15
# Chennai         14
# Kashipur        13
# Nashik          12
# Ahmedabad       12
# Chandrapur      12
# Mumbai          11
# Haldwani        11
# Hakdwani        10
# Faridabad        9
# Delhi            8
# Gurugram         8
# pune             8
# Rewari           8
# Patiyala         8
# Nabha            8
# Bengaluru        8
# Serampore        7
# Karnal           7
# Jalandhar        6
# Haldwani         6
# solapur          5
# pUNE             5
# New Delhi        5
# nashik           5
# Jhansi           4
# Name: count, dtype: int64

# %%
df1.marital_stat.value_counts()
# Out:
# marital_stat
# Single     631
# Married    359
# Name: count, dtype: int64

# %%
df1.family_count.value_counts()
# Out:
# family_count
# 4    511
# 5    156
# 3    126
# 6     50
# 8     44
# 2     32
# 0     28
# 1     24
# 7     19
# Name: count, dtype: int64

# %%
df1.preferred_ev_type.value_counts()
# Out:
# preferred_ev_type
# SUV          462
# Sedan        237
# Hatchback    144
# Liftback     118
# Cabrio        29
# Name: count, dtype: int64

# %%
df1.think_ev_are_economical.value_counts()
# Out:
# think_ev_are_economical
# Yes      760
# Maybe    123
# No       107
# Name: count, dtype: int64

# %%
df1.preferred_brand.value_counts()
# Out:
# preferred_brand
# Tata             184
# Hyundai          164
# Honda            143
# KIA              142
# Nissan           121
# Maruti            58
# MG                55
# Volkswagen        42
# McLaren           18
# Chevrolet         13
# BMW               12
# Maruti Suzuki     11
# Audi               9
# Suzuki             7
# Maruti             7
# Nexa               4
# Name: count, dtype: int64

# %%
df1.preferred_price_range.value_counts()
# Out:
# preferred_price_range
# <15 lakhs    479
# <5 lakhs     285
# <25 lakhs    145
# >25 lakhs     34
# 1200000       14
# 2000000       12
# 1500000       11
# 700000        10
# Name: count, dtype: int64

# %%
df1["preferred_price_range"]=df1["preferred_price_range"].replace({"<15 lakhs":15,"<5 lakhs":5,"<25 lakhs":25,">25 lakhs":30,"1200000":12,"1500000" :15,"700000":7})

# %%
df1
# Out:
#      age       city marital_stat  family_count  annual_income replace_with_ev  \
# 0     30  New Delhi       Single             4   1.770466e+06             Yes
# 1     27  Ahmedabad       Single             4   7.600731e+05             Yes
# 2     28       Pune       Single             4   2.779701e+06           Maybe
# 3     26       Pune       Single             4   1.473698e+06             Yes
# 4     25       Pune       Single             4   2.430643e+06             Yes
# ..   ...        ...          ...           ...            ...             ...
# 985   32      Delhi       Single             3   2.259379e+06           Maybe
# 986   30      Pune        Single             5   3.353677e+06             Yes
# 987   31       Pune       Single             2   5.689586e+05             Yes
# 988   31       Pune      Married             4   3.162609e+06             Yes
# 989   27       Pune       Single             4   2.042527e+06             Yes
#
# ...

# %%
df1["preferred_wheel_count"].value_counts()
# Out:
# preferred_wheel_count
# 4    623
# 2    276
# 3     91
# Name: count, dtype: int64

# %%
city = df1["city"].value_counts()

# %%
city
# Out:
# city
# Pune           565
# Mumbai          45
# Pune            37
# Delhi           24
# Nagpur          22
# Satara          21
# New Delhi       19
# Nellore         17
# Banglore        15
# Noida           15
# Chennai         14
# Kashipur        13
# Nashik          12
# Ahmedabad       12
# Chandrapur      12
# Mumbai          11
# Haldwani        11
# Hakdwani        10
# Faridabad        9
# Delhi            8
# Gurugram         8
# pune             8
# Rewari           8
# Patiyala         8
# Nabha            8
# Bengaluru        8
# Serampore        7
# Karnal           7
# Jalandhar        6
# Haldwani         6
# solapur          5
# pUNE             5
# New Delhi        5
# nashik           5
# Jhansi           4
# Name: count, dtype: int64

# %%
df1["city"] = df1["city"].replace({"Pune":"Pune", "pUNE": "Pune", "pune": "Pune", "Pune ": "Pune"})
df1["city"] = df1["city"].replace({"Mumbai ":"Mumbai", "Mumbai": "Mumbai"})
df1["city"] = df1["city"].replace({"Banglore ":"Bengaluru"})
df1["city"] = df1["city"].replace({"nashik":"Nashik"})
df1["city"] = df1["city"].replace({"Delhi":"New Delhi", "Delhi ": "New Delhi", "New Delhi ": "New Delhi"})
df1["city"] = df1["city"].replace({"Hakdwani":"Haldwani", "Haldwani ": "Haldwani"})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      990 non-null    int64
#  1   city                     990 non-null    object
#  2   marital_stat             990 non-null    object
#  3   family_count             990 non-null    int64
#  4   annual_income            990 non-null    float64
#  5   replace_with_ev          990 non-null    object
#  6   preferred_ev_type        990 non-null    object
#  7   think_ev_are_economical  990 non-null    object
#  8   preferred_brand          990 non-null    object
#  9   preferred_price_range    990 non-null    object
#  10  preferred_wheel_count    990 non-null    int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 85.2+ KB

# %%
# encoding the label 
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
df1.columns
# Out:
# Index(['age', 'city', 'marital_stat', 'family_count', 'annual_income',
#        'replace_with_ev', 'preferred_ev_type', 'think_ev_are_economical',
#        'preferred_brand', 'preferred_price_range', 'preferred_wheel_count'],
#       dtype='object')

# %%
df1["city"].shape
# Out:
# (990,)

# %%
df1["city"] = label.fit_transform(df1["city"].astype(str))
df1['marital_stat'] = label.fit_transform(df1['marital_stat'].astype(str))
df1['replace_with_ev'] = label.fit_transform(df1['replace_with_ev'].astype(str))
df1['preferred_ev_type'] = label.fit_transform(df1['preferred_ev_type'].astype(str))
df1["think_ev_are_economical"] = label.fit_transform(df1["think_ev_are_economical"].astype(str))
df1['preferred_brand'] = label.fit_transform(df1['preferred_brand'].astype(str))
df1['preferred_price_range'] = label.fit_transform(df1['preferred_price_range'].astype(str))

# %%
df1
# Out:
#      age  city  marital_stat  family_count  annual_income  replace_with_ev  \
# 0     30     8             1             4   1.770466e+06                2
# 1     27     0             1             4   7.600731e+05                2
# 2     28    11             1             4   2.779701e+06                0
# 3     26    11             1             4   1.473698e+06                2
# 4     25    11             1             4   2.430643e+06                2
# ..   ...   ...           ...           ...            ...              ...
# 985   32     8             1             3   2.259379e+06                0
# 986   30    11             1             5   3.353677e+06                2
# 987   31    11             1             2   5.689586e+05                2
# 988   31    11             0             4   3.162609e+06                2
# 989   27    11             1             4   2.042527e+06                2
#
#      preferred_ev_type  think_ev_are_economical  preferred_brand  \
# ...

# %%
col_avg =round(df1.mean(),2)
col_avg
# Out:
# age                             31.80
# city                            10.31
# marital_stat                     0.64
# family_count                     4.12
# annual_income              2261179.88
# replace_with_ev                  1.46
# preferred_ev_type                2.74
# think_ev_are_economical          1.64
# preferred_brand                  8.33
# preferred_price_range            2.60
# preferred_wheel_count            3.35
# dtype: float64

# %%
plt.figure(figsize = (16,8))
sns.heatmap(df1.corr(),annot = True)
plt.show()

# %%
# scaling the values 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_values = pd.DataFrame(scaler.fit_transform(df1) , columns = df1.columns)

# %%
scaled_values
# Out:
#           age      city  marital_stat  family_count  annual_income  \
# 0   -0.159835 -0.563428      0.754280     -0.079089      -0.490254
# 1   -0.425929 -2.518884      0.754280     -0.079089      -1.499700
# 2   -0.337231  0.169868      0.754280     -0.079089       0.518035
# 3   -0.514627  0.169868      0.754280     -0.079089      -0.786744
# 4   -0.603325  0.169868      0.754280     -0.079089       0.169305
# ..        ...       ...           ...           ...            ...
# 985  0.017560 -0.563428      0.754280     -0.759942      -0.001799
# 986 -0.159835  0.169868      0.754280      0.601764       1.091473
# 987 -0.071137  0.169868      0.754280     -1.440795      -1.690635
# 988 -0.071137  0.169868     -1.325768     -0.079089       0.900584
# 989 -0.425929  0.169868      0.754280     -0.079089      -0.218448
#
#      replace_with_ev  preferred_ev_type  think_ev_are_economical  \
# 0           0.669051           0.242489                 0.515782
# ...

# %%
# applying PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)

# %%
pca_data = pca.fit_transform(scaled_values)

# %%
pca_data
# Out:
# array([[-0.5584457 ,  1.11336936],
#        [ 0.18787124,  1.28312274],
#        [-0.94449878,  0.11375212],
#        ...,
#        [ 1.98544838, -0.82795125],
#        [ 0.90841857,  0.22621952],
#        [ 0.00439433,  1.01707567]])

# %%
pca_data = pd.DataFrame(pca_data , columns = ["PCA1" , "PCA2"])
pca_data
# Out:
#          PCA1      PCA2
# 0   -0.558446  1.113369
# 1    0.187871  1.283123
# 2   -0.944499  0.113752
# 3    0.492140  0.935645
# 4    0.292913  0.755920
# ..        ...       ...
# 985 -0.704476 -0.299727
# 986 -0.003906  1.501346
# 987  1.985448 -0.827951
# 988  0.908419  0.226220
# 989  0.004394  1.017076
#
# [990 rows x 2 columns]

# %% [markdown]
# ## K-Means clustering algorithm

# %%
from sklearn.cluster import KMeans

# %%
wcss = [] 
for i in range(1,11):
 kmeans = KMeans(n_clusters = i , init = "k-means++" , random_state = 30)
 kmeans.fit(scaled_values)
 wcss.append(kmeans.inertia_)
# Out:
# C:\Users\BHASKAR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\BHASKAR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\BHASKAR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [10890.000000000002,
#  9890.857934547648,
#  9225.182373582282,
#  8634.080069668727,
#  8137.702378666991,
#  7696.266593374174,
#  7294.220466182674,
#  6938.1444050154,
#  6756.280950062481,
#  6569.425234883605]

# %%
# plotting the kmeans graph between k and wcss
range_val = range(1,11)
plt.plot(range_val,wcss, marker = "o")
plt.xlabel('the number of cluster ')
plt.xticks(np.arange(1,11,1))
plt.ylabel('Inertia')
plt.title('Scree/ Elbow Plot')
plt.show()

# %%
wcss = [] 
for i in range(1,11):
 kmeans = KMeans(n_clusters = i , init = "k-means++" , random_state = 30)
 kmeans.fit(df1)
 wcss.append(kmeans.inertia_)
# Out:
# C:\Users\BHASKAR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\BHASKAR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\BHASKAR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(1,11),wcss,marker="o")
plt.xlabel("k values")
plt.xticks(np.arange(1,11,1))
plt.ylabel("Inertia")
plt.title("Elbow Plot")
plt.show()

# %% [markdown]
# ### we get k value = 3

# %%
model = KMeans(4)
model.fit_predict(pca_data)
pca_df_kmeans = pd.concat([pca_data, pd.DataFrame({'cluster': model.labels_})], axis = 1)
# Out:
# C:\Users\BHASKAR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\BHASKAR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
pca_df_kmeans
# Out:
#          PCA1      PCA2  cluster
# 0   -0.558446  1.113369        1
# 1    0.187871  1.283123        1
# 2   -0.944499  0.113752        3
# 3    0.492140  0.935645        1
# 4    0.292913  0.755920        1
# ..        ...       ...      ...
# 985 -0.704476 -0.299727        3
# 986 -0.003906  1.501346        1
# 987  1.985448 -0.827951        2
# 988  0.908419  0.226220        2
# 989  0.004394  1.017076        1
#
# [990 rows x 3 columns]

# %%
## Creating a target column 'Cluster' for storing clustered segments
new_df = pd.concat([df1, pd.DataFrame({'Cluster': model.labels_})], axis = 1)
new_df.head()
# Out:
#    age  city  marital_stat  family_count  annual_income  replace_with_ev  \
# 0   30     8             1             4   1.770466e+06                2
# 1   27     0             1             4   7.600731e+05                2
# 2   28    11             1             4   2.779701e+06                0
# 3   26    11             1             4   1.473698e+06                2
# 4   25    11             1             4   2.430643e+06                2
#
#    preferred_ev_type  think_ev_are_economical  preferred_brand  \
# 0                  3                        2               12
# 1                  3                        2                4
# 2                  4                        2                9
# 3                  4                        2                6
# 4                  4                        2               10
#
#    preferred_price_range  preferred_wheel_count  Cluster
# 0                      5                      2        1
# ...

# %%
sns.countplot(x = 'Cluster', data = new_df)
# Out:
# <Axes: xlabel='Cluster', ylabel='count'>

# %%
c_drop_new_df = new_df.drop(['Cluster'], axis = 1)

for c in c_drop_new_df:
    grid = sns.FacetGrid(new_df, col = 'Cluster')
    grid = grid.map(plt.hist, c)
plt.show()

# %% [markdown]
# Ages 28 - 30 are to be targeted

# %%
cluster_count = new_df['Cluster'].value_counts()
cluster_count

# %%
df4 = new_df.copy()
df4.shape

# %%
df5 = pd.concat([ev_data, pd.DataFrame({'Cluster': model.labels_})], axis = 1)
df5.head()
